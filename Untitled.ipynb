# %%
#pip install pandas numpy scikit-learn matplotlib seaborn

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import pi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
# Load the dataset (Replace 'your_data.csv' with the actual file path)
data = pd.read_csv('RawFishDataMerged.csv',encoding='ISO-8859-1')

# %%
# Preview the data
#print(data.head())
data.info()
print(data.columns)
column_names = data.columns.tolist()
print(column_names)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Columns: 790 entries, Fish sample to Unnamed: 789
# dtypes: float64(745), object(45)
# memory usage: 567.9+ KB
# Index(['Fish sample', 'Colour', 'Odour', 'Texture', 'Flavour', 'Appearance',
#        'Insect Invasion', 'Overall Acceptability', 'Market', 'State',
#        ...
#        'Unnamed: 780', 'Unnamed: 781', 'Unnamed: 782', 'Unnamed: 783',
#        'Unnamed: 784', 'Unnamed: 785', 'Unnamed: 786', 'Unnamed: 787',
#        'Unnamed: 788', 'Unnamed: 789'],
#       dtype='object', length=790)
# ['Fish sample', 'Colour', 'Odour', 'Texture', 'Flavour', 'Appearance', 'Insect Invasion', 'Overall Acceptability', 'Market', 'State', 'TBA', 'PBC', 'TFC', 'Pigmentation', 'Elevation', 'Texture.1', 'Margin', 'Shape', 'Optical Density', 'Pigmentation.1', 'Elevation.1', 'Texture.2', 'Margin.1', 'Shape.1', 'Optical Density.1', 'Pigmentation.2', 'Elevation.2', 'Texture.3', 'Margin.2', 'Shape.2', 'Optical Density.2', 'pH', 'Lipid oxidation', 'Moisture Content', 'Protein', 'Fat', 'Ash', 'Escherichia coli', 'Salmonella', 'Shigella', 'Staphylococcus', 'Aspergillus flavus', 'Aspergillus occultus', 'Aspergillus niger', 'Aspergillus nidulans ', 'Penicillum chrysogenum', 'Aspergillus fumigatus', 'Rhizopus stolonifer', 'Candida krusei', 'Aspergillus terreus', 'Aspergillus ochraceus', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79', 'Unnamed: 80', 'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84', 'Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88', 'Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91', 'Unnamed: 92', 'Unnamed: 93', 'Unnamed: 94', 'Unnamed: 95', 'Unnamed: 96', 'Unnamed: 97', 'Unnamed: 98', 'Unnamed: 99', 'Unnamed: 100', 'Unnamed: 101', 'Unnamed: 102', 'Unnamed: 103', 'Unnamed: 104', 'Unnamed: 105', 'Unnamed: 106', 'Unnamed: 107', 'Unnamed: 108', 'Unnamed: 109', 'Unnamed: 110', 'Unnamed: 111', 'Unnamed: 112', 'Unnamed: 113', 'Unnamed: 114', 'Unnamed: 115', 'Unnamed: 116', 'Unnamed: 117', 'Unnamed: 118', 'Unnamed: 119', 'Unnamed: 120', 'Unnamed: 121', 'Unnamed: 122', 'Unnamed: 123', 'Unnamed: 124', 'Unnamed: 125', 'Unnamed: 126', 'Unnamed: 127', 'Unnamed: 128', 'Unnamed: 129', 'Unnamed: 130', 'Unnamed: 131', 'Unnamed: 132', 'Unnamed: 133', 'Unnamed: 134', 'Unnamed: 135', 'Unnamed: 136', 'Unnamed: 137', 'Unnamed: 138', 'Unnamed: 139', 'Unnamed: 140', 'Unnamed: 141', 'Unnamed: 142', 'Unnamed: 143', 'Unnamed: 144', 'Unnamed: 145', 'Unnamed: 146', 'Unnamed: 147', 'Unnamed: 148', 'Unnamed: 149', 'Unnamed: 150', 'Unnamed: 151', 'Unnamed: 152', 'Unnamed: 153', 'Unnamed: 154', 'Unnamed: 155', 'Unnamed: 156', 'Unnamed: 157', 'Unnamed: 158', 'Unnamed: 159', 'Unnamed: 160', 'Unnamed: 161', 'Unnamed: 162', 'Unnamed: 163', 'Unnamed: 164', 'Unnamed: 165', 'Unnamed: 166', 'Unnamed: 167', 'Unnamed: 168', 'Unnamed: 169', 'Unnamed: 170', 'Unnamed: 171', 'Unnamed: 172', 'Unnamed: 173', 'Unnamed: 174', 'Unnamed: 175', 'Unnamed: 176', 'Unnamed: 177', 'Unnamed: 178', 'Unnamed: 179', 'Unnamed: 180', 'Unnamed: 181', 'Unnamed: 182', 'Unnamed: 183', 'Unnamed: 184', 'Unnamed: 185', 'Unnamed: 186', 'Unnamed: 187', 'Unnamed: 188', 'Unnamed: 189', 'Unnamed: 190', 'Unnamed: 191', 'Unnamed: 192', 'Unnamed: 193', 'Unnamed: 194', 'Unnamed: 195', 'Unnamed: 196', 'Unnamed: 197', 'Unnamed: 198', 'Unnamed: 199', 'Unnamed: 200', 'Unnamed: 201', 'Unnamed: 202', 'Unnamed: 203', 'Unnamed: 204', 'Unnamed: 205', 'Unnamed: 206', 'Unnamed: 207', 'Unnamed: 208', 'Unnamed: 209', 'Unnamed: 210', 'Unnamed: 211', 'Unnamed: 212', 'Unnamed: 213', 'Unnamed: 214', 'Unnamed: 215', 'Unnamed: 216', 'Unnamed: 217', 'Unnamed: 218', 'Unnamed: 219', 'Unnamed: 220', 'Unnamed: 221', 'Unnamed: 222', 'Unnamed: 223', 'Unnamed: 224', 'Unnamed: 225', 'Unnamed: 226', 'Unnamed: 227', 'Unnamed: 228', 'Unnamed: 229', 'Unnamed: 230', 'Unnamed: 231', 'Unnamed: 232', 'Unnamed: 233', 'Unnamed: 234', 'Unnamed: 235', 'Unnamed: 236', 'Unnamed: 237', 'Unnamed: 238', 'Unnamed: 239', 'Unnamed: 240', 'Unnamed: 241', 'Unnamed: 242', 'Unnamed: 243', 'Unnamed: 244', 'Unnamed: 245', 'Unnamed: 246', 'Unnamed: 247', 'Unnamed: 248', 'Unnamed: 249', 'Unnamed: 250', 'Unnamed: 251', 'Unnamed: 252', 'Unnamed: 253', 'Unnamed: 254', 'Unn ...

# %%
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# %%
column_names = data.columns.tolist()
print(column_names)
# Out:
# ['Fish sample', 'Colour', 'Odour', 'Texture', 'Flavour', 'Appearance', 'Insect Invasion', 'Overall Acceptability', 'Market', 'State', 'TBA', 'PBC', 'TFC', 'Pigmentation', 'Elevation', 'Texture.1', 'Margin', 'Shape', 'Optical Density', 'Pigmentation.1', 'Elevation.1', 'Texture.2', 'Margin.1', 'Shape.1', 'Optical Density.1', 'Pigmentation.2', 'Elevation.2', 'Texture.3', 'Margin.2', 'Shape.2', 'Optical Density.2', 'pH', 'Lipid oxidation', 'Moisture Content', 'Protein', 'Fat', 'Ash', 'Escherichia coli', 'Salmonella', 'Shigella', 'Staphylococcus', 'Aspergillus flavus', 'Aspergillus occultus', 'Aspergillus niger', 'Aspergillus nidulans ', 'Penicillum chrysogenum', 'Aspergillus fumigatus', 'Rhizopus stolonifer', 'Candida krusei', 'Aspergillus terreus', 'Aspergillus ochraceus']

# %%
data.head()
# Out:
#   Fish sample        Colour       Odour      Texture     Flavour  \
# 0        FAM1   Dark Brown    Moderate     Moderate        Good
# 1        FAM2         Dark   Very Good         Hard        Good
# 2        FAM3         Dark        Good    Very hard   Very Good
# 3        FAT1    Dark Brown  Very Good   Very Hard    Very Good
# 4        FAT2  Light Brown   Moderate      Moderate        Good
#
#         Appearance Insect Invasion Overall Acceptability     Market  State  \
# 0       Attractive          Absent             Moderate     Mandate  Kwara
# 1  Very Attractive          Absent            Very High     Mandate  Kwara
# 2   Not Attractive          Absent                 High     Mandate  Kwara
# 3  Very Attractive          Absent            Very High   Oja Titun  Kwara
# 4   Not Attractive          Absent                  Low   Oja Titun  Kwara
#
#    ... Aspergillus flavus Aspergillus occultus Aspergillus niger  \
# 0  ...            Present              Present            Absent
# 1  ...            Present              Present            Absent
# 2  ...            Present              Present            Absent
# 3  ...            Present              Present            Absent
# 4  ...             Absent              Present            Absent
#
#   Aspergillus nidulans  Penicillum chrysogenum Aspergillus fumigatus  \
# 0                Absent                 Absent                Absent
# 1                Absent                 Absent                Absent
# 2                Absent                 Absent                Absent
# 3                Absent                 Absent                Absent
# 4                Absent                 Absent                Absent
#
#   Rhizopus stolonifer Candida krusei Aspergillus terreus Aspergillus ochraceus
# 0              Absent         Absent              Absent                Absent
# 1              Absent         Absent              Absent                Absent
# 2              Absent         Absent              Absent                Absent
# 3              Absent         Absent              Absent                Absent
# 4              Absent         Absent              Absent                Absent
#
# [5 rows x 51 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Fish sample             90 non-null     object
#  1   Colour                  90 non-null     object
#  2   Odour                   90 non-null     object
#  3   Texture                 90 non-null     object
#  4   Flavour                 90 non-null     object
#  5   Appearance              90 non-null     object
#  6   Insect Invasion         90 non-null     object
#  7   Overall Acceptability   90 non-null     object
#  8   Market                  90 non-null     object
#  9   State                   90 non-null     object
#  10  TBA                     90 non-null     object
#  11  PBC                     90 non-null     object
#  12  TFC                     90 non-null     object
#  13  Pigmentation            90 non-null     object
#  14  Elevation               90 non-null     object
#  15  Texture.1               90 non-null     object
#  16  Margin                  90 non-null     object
#  17  Shape                   90 non-null     object
#  18  Optical Density         90 non-null     object
#  19  Pigmentation.1          90 non-null     object
#  20  Elevation.1             90 non-null     object
#  21  Texture.2               90 non-null     object
#  22  Margin.1                90 non-null     object
#  23  Shape.1                 90 non-null     object
#  24  Optical Density.1       90 non-null     object
#  25  Pigmentation.2          90 non-null     object
#  26  Elevation.2             90 non-null     object
#  27  Texture.3               90 non-null     object
#  28  Margin.2                90 non-null     object
#  29  Shape.2                 90 non-null     object
#  30  Optical Density.2       90 non-null     object
#  31  pH                      90 non-null     float64
#  32  Lipid oxidation         90 non-null     float64
#  33  Moisture Content        90 non-null     float64
#  34  Protein                 90 non-null     float64
#  35  Fat                     90 non-null     float64
#  36  Ash                     90 non-null     float64
#  37  Escherichia coli        90 non-null     object
#  38  Salmonella              90 non-null     object
#  39  Shigella                90 non-null     object
#  40  Staphylococcus          90 non-null     object
#  41  Aspergillus flavus      90 non-null     object
#  42  Aspergillus occultus    90 non-null     object
#  43  Aspergillus niger       90 non-null     object
#  44  Aspergillus nidulans    89 non-null     object
#  45  Penicillum chrysogenum  90 non-null     object
#  46  Aspergillus fumigatus   90 non-null     object
#  47  Rhizopus stolonifer     90 non-null     object
#  48  Candida krusei          90 non-null     object
#  49  Aspergillus terreus     90 non-null     object
#  50  Aspergillus ochraceus   90 non-null     object
# dtypes: float64(6), object(45)
# memory usage: 36.8+ KB

# %%
df = pd.DataFrame(data)
df = df.replace(mapping)
# Separate float fields for later use
# Separate float and integer fields for later use
numeric_fields = df.select_dtypes(include=['float64', 'int64'])

# Drop numeric columns to prepare for encoding only categorical fields
df_to_encode = df.select_dtypes(exclude=['float64', 'int64'])

# Ensure that all categorical columns are strings (to prevent errors)
df_to_encode = df_to_encode.astype(str)

# Initialize LabelEncoder
le = LabelEncoder()

# Apply LabelEncoder to each column in the categorical DataFrame
for column in df_to_encode.columns:
    df_to_encode[column] = le.fit_transform(df_to_encode[column])

# Merge the encoded fields and the numeric fields back together
df_merged = pd.concat([df_to_encode, numeric_fields], axis=1)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Fish sample             92 non-null     int32
#  1   Colour                  92 non-null     int32
#  2   Odour                   92 non-null     int32
#  3   Texture                 92 non-null     int32
#  4   Flavour                 92 non-null     int32
#  5   Appearance              92 non-null     int32
#  6   Insect Invasion         92 non-null     int32
#  7   Overall Acceptability   92 non-null     int32
#  8   Market                  92 non-null     int32
#  9   State                   92 non-null     int32
#  10  TBA                     92 non-null     int32
#  11  PBC                     92 non-null     int32
#  12  TFC                     92 non-null     int32
#  13  Pigmentation            92 non-null     int32
#  14  Elevation               92 non-null     int32
#  15  Texture.1               92 non-null     int32
#  16  Margin                  92 non-null     int32
#  17  Shape                   92 non-null     int32
#  18  Optical Density         92 non-null     int32
#  19  Pigmentation.1          92 non-null     int32
#  20  Elevation.1             92 non-null     int32
#  21  Texture.2               92 non-null     int32
#  22  Margin.1                92 non-null     int32
#  23  Shape.1                 92 non-null     int32
#  24  Optical Density.1       92 non-null     int32
#  25  Pigmentation.2          92 non-null     int32
#  26  Elevation.2             92 non-null     int32
#  27  Texture.3               92 non-null     int32
#  28  Margin.2                92 non-null     int32
#  29  Shape.2                 92 non-null     int32
#  30  Optical Density.2       92 non-null     int32
#  31  Escherichia coli        92 non-null     int32
#  32  Salmonella              92 non-null     int32
#  33  Shigella                92 non-null     int32
#  34  Staphylococcus          92 non-null     int32
#  35  Aspergillus flavus      92 non-null     int32
#  36  Aspergillus occultus    92 non-null     int32
#  37  Aspergillus niger       92 non-null     int32
#  38  Aspergillus nidulans    92 non-null     int32
#  39  Penicillum chrysogenum  92 non-null     int32
#  40  Aspergillus fumigatus   92 non-null     int32
#  41  Rhizopus stolonifer     92 non-null     int32
#  42  Candida krusei          92 non-null     int32
#  43  Aspergillus terreus     92 non-null     int32
#  44  Aspergillus ochraceus   92 non-null     int32
#  45  pH                      90 non-null     float64
#  46  Lipid oxidation         90 non-null     float64
#  47  Moisture Content        90 non-null     float64
#  48  Protein                 90 non-null     float64
#  49  Fat                     90 non-null     float64
#  50  Ash                     90 non-null     float64
# dtypes: float64(6), int32(45)
# memory usage: 20.6 KB

# %%
df_merged.head(10)
# Out:
#    Fish sample  Colour  Odour  Texture  Flavour  Appearance  Insect Invasion  \
# 0            3       7      6        5        3           2                2
# 1            4       4      9        3        3           3                2
# 2            5       4      4       12        8           1                2
# 3            9       6      9       11        8           3                2
# 4           10      10      7        5        3           1                2
# 5           11       6      6        3        0           2                2
# 6            6       9      5       11        5           1                2
# 7            7       6      5        5        3           2                2
# 8            8       9      4       11        5           2                2
# 9            0       9      2       11        2           2                4
#
#    Overall Acceptability  Market  State  ...  Rhizopus stolonifer  \
# 0                     11      20      3  ...                    1
# 1                     12      20      3  ...                    1
# 2                      8      20      3  ...                    1
# 3                     12      24      3  ...                    1
# 4                     10      24      3  ...                    1
# 5                     11      24      3  ...                    1
# 6                      5      23      3  ...                    1
# 7                     12      23      3  ...                    1
# 8                      7      23      3  ...                    1
# 9                      8      12      3  ...                    1
#
#    Candida krusei  Aspergillus terreus  Aspergillus ochraceus    pH  \
# 0               1                    1                      1  7.67
# 1               1                    1                      1  7.23
# 2               1                    1                      1  7.19
# 3               1                    1                      1  7.10
# 4               1                    1                      1  6.91
# 5               1                    1                      1  6.50
# 6               1                    1                      1  7.48
# 7               1                    1                      1  7.11
# 8               1                    1                      1  7.34
# 9               1                    1                      1  6.62
#
#    Lipid oxidation  Moisture Content  Protein   Fat   Ash
# 0           1.0444             11.70    20.60  8.40  3.40
# 1           0.9234              9.80    20.80  8.10  3.60
# 2           0.9033              9.20    20.84  8.22  3.44
# 3           0.6767             19.30    20.44  8.42  3.48
# 4           1.4706             12.14    19.76  9.00  3.46
# 5           0.8623             14.10    19.63  9.16  3.44
# 6           0.8159             19.97    21.70  9.10  3.50
# 7           1.3357             15.10    21.40  8.60  3.50
# 8           1.1694             13.68    20.50  9.15  3.52
# 9           0.9014             19.76    20.00  8.53  3.48
#
# [10 rows x 51 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline

df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Fish sample             92 non-null     int32
#  1   Colour                  92 non-null     int32
#  2   Odour                   92 non-null     int32
#  3   Texture                 92 non-null     int32
#  4   Flavour                 92 non-null     int32
#  5   Appearance              92 non-null     int32
#  6   Insect Invasion         92 non-null     int32
#  7   Overall Acceptability   92 non-null     int32
#  8   Market                  92 non-null     int32
#  9   State                   92 non-null     int32
#  10  TBA                     92 non-null     int32
#  11  PBC                     92 non-null     int32
#  12  TFC                     92 non-null     int32
#  13  Pigmentation            92 non-null     int32
#  14  Elevation               92 non-null     int32
#  15  Texture.1               92 non-null     int32
#  16  Margin                  92 non-null     int32
#  17  Shape                   92 non-null     int32
#  18  Optical Density         92 non-null     int32
#  19  Pigmentation.1          92 non-null     int32
#  20  Elevation.1             92 non-null     int32
#  21  Texture.2               92 non-null     int32
#  22  Margin.1                92 non-null     int32
#  23  Shape.1                 92 non-null     int32
#  24  Optical Density.1       92 non-null     int32
#  25  Pigmentation.2          92 non-null     int32
#  26  Elevation.2             92 non-null     int32
#  27  Texture.3               92 non-null     int32
#  28  Margin.2                92 non-null     int32
#  29  Shape.2                 92 non-null     int32
#  30  Optical Density.2       92 non-null     int32
#  31  Escherichia coli        92 non-null     int32
#  32  Salmonella              92 non-null     int32
#  33  Shigella                92 non-null     int32
#  34  Staphylococcus          92 non-null     int32
#  35  Aspergillus flavus      92 non-null     int32
#  36  Aspergillus occultus    92 non-null     int32
#  37  Aspergillus niger       92 non-null     int32
#  38  Aspergillus nidulans    92 non-null     int32
#  39  Penicillum chrysogenum  92 non-null     int32
#  40  Aspergillus fumigatus   92 non-null     int32
#  41  Rhizopus stolonifer     92 non-null     int32
#  42  Candida krusei          92 non-null     int32
#  43  Aspergillus terreus     92 non-null     int32
#  44  Aspergillus ochraceus   92 non-null     int32
#  45  pH                      90 non-null     float64
#  46  Lipid oxidation         90 non-null     float64
#  47  Moisture Content        90 non-null     float64
#  48  Protein                 90 non-null     float64
#  49  Fat                     90 non-null     float64
#  50  Ash                     90 non-null     float64
# dtypes: float64(6), int32(45)
# memory usage: 20.6 KB

# %%
# Assuming df is your DataFrame
# X = features, y = multiple target labels (microbial organisms)
X = df_merged.drop(columns=['Escherichia coli', 'Salmonella', 'Shigella','Staphylococcus','Aspergillus flavus','Aspergillus occultus',
                     'Aspergillus niger', 'Aspergillus nidulans ', 'Penicillum chrysogenum', 'Aspergillus fumigatus',
                     'Rhizopus stolonifer', 'Candida krusei',  'Aspergillus terreus', 'Aspergillus ochraceus']) 
# Drop target columns
y = df_merged[['Escherichia coli', 'Salmonella', 'Shigella','Staphylococcus','Aspergillus flavus','Aspergillus occultus',
                     'Aspergillus niger', 'Aspergillus nidulans ', 'Penicillum chrysogenum', 'Aspergillus fumigatus',
                     'Rhizopus stolonifer', 'Candida krusei',  'Aspergillus terreus', 'Aspergillus ochraceus']] 
# The multiple labels (target)

from sklearn.preprocessing import OneHotEncoder

# OneHotEncode the target variables
encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y)  # This transforms multiclass targets to multilabel (binary)

# Continue with model training
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Train and evaluate the model as usual
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Evaluate
print(classification_report(y_test, y_pred, zero_division=1))

print(y_test.shape)
print(y_pred.shape)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.78      0.74         9
#            1       0.78      0.70      0.74        10
#            2       1.00      1.00      1.00         0
#            3       1.00      1.00      1.00         0
#            4       0.50      0.67      0.57         3
#            5       0.86      0.80      0.83        15
#            6       1.00      0.00      0.00         1
#            7       1.00      1.00      1.00         0
#            8       0.83      0.71      0.77         7
#            9       0.75      0.75      0.75        12
#           10       1.00      1.00      1.00         0
#           11       1.00      0.17      0.29         6
#           12       0.65      0.92      0.76        12
#           13       1.00      0.00      0.00         1
#           14       1.00      1.00      1.00         0
#           15       1.00      0.25      0.40         4
#           16       0.82      0.93      0.88        15
#           17       1.00      1.00      1.00         0
#           18       0.83      0.83      0.83         6
#           19       1.00      0.92      0.96        13
#           20       1.00      1.00      1.00         0
#           21       1.00      0.00      0.00         3
#           22       0.83      0.94      0.88        16
#           23       1.00      1.00      1.00         0
#           24       1.00      0.00      0.00         3
#           25       0.79      1.00      0.88        15
#           26       1.00      0.00      0.00         1
#           27       1.00      0.83      0.91         6
#           28       0.92      0.92      0.92        13
#           29       1.00      1.00      1.00         0
#           30       1.00      0.00      0.00         1
#           31       0.95      1.00      0.97        18
#           32       1.00      1.00      1.00         0
#           33       0.50      1.00      0.67         1
#           34       1.00      0.94      0.97        18
#           35       1.00      1.00      1.00         0
#           36       1.00      0.00      0.00         1
#           37       0.95      1.00      0.97        18
#           38       1.00      1.00      1.00         0
#           39       1.00      1.00      1.00         0
#           40       1.00      1.00      1.00        19
#           41       1.00      1.00      1.00         0
#           42       1.00      1.00      1.00         0
#           43       1.00      1.00      1.00        19
#           44       1.00      1.00      1.00         0
#
#    micro avg       0.87      0.85      0.86       266
#    macro avg       0.93      0.76      0.75       266
# weighted avg       0.89      0.85      0.83       266
#  samples avg       0.87      0.85      0.86       266
#
# (19, 45)
# (19, 45)

# %%
print(y_test.shape)
print(y_pred.shape)
# Out:
# (19, 14)
# (19, 14)

# %%
import pickle
file_path = 'microbial_model.pkl'
with open(file_path, 'wb') as file:
    pickle.dump(y_pred, file)
print(f"Model saved to {file_path}")
# Out:
# Model saved to microbial_model.pkl
